# %% [markdown]
# This is a notebook **solely for use by Drake's release managers**.  Only run this notebook per the instructions at the [release playbook](https://drake.mit.edu/release_playbook.html), never at any other moment.  There are several steps of preparation that must be performed first, prior to running this notebook.

# %%
# Compute the list of files that will be added and removed.
from glob import glob
from os.path import basename

def archive_path(base):
    return f"/opt/drake/share/drake/tutorials/{base}"

def work_path(base):
    return f"/work/{base}"

# Absolute paths.
released_paths = sorted(glob(archive_path("*.ipynb")))

# File names only, no paths.
released = [basename(x) for x in released_paths]

def print_list(heading, items):
    print(heading)
    if not items:
        print(" (None)")
    for item in items:
        print(f"- {item}")
    print()

print_list("Released tutorials:", released)
# Out:
# Released tutorials:
# - authoring_leaf_systems.ipynb
# - authoring_multibody_simulation.ipynb
# - debug_mathematical_program.ipynb
# - dynamical_systems.ipynb
# - hydroelastic_contact_basics.ipynb
# - hydroelastic_contact_nonconvex_mesh.ipynb
# - index.ipynb
# - licensed_solvers_deepnote.ipynb
# - linear_program.ipynb
# - mathematical_program.ipynb
# - mathematical_program_multibody_plant.ipynb
# - multibody_plant_autodiff_mass.ipynb
# - nonlinear_program.ipynb
# - pyplot_animation_multibody_plant.ipynb
# - quadratic_program.ipynb
# - rendering_multibody_plant.ipynb
# - solver_parameters.ipynb
# - sum_of_squares_optimization.ipynb
# - updating_costs_and_constraints.ipynb
# - working_with_diagrams.ipynb

# %% [markdown]
# **Inspect the above list of added and removed files before proceeding! There should be approximately two dozen files listed (the set of tutorials). These are the tutorials that you'll be deploying.**

# %%
import shutil
yyyymmdd = open('/opt/drake/share/doc/drake/VERSION.TXT').read().split()[0]
print(f"You are about to deploy version {yyyymmdd}.")
print(f"Type 'yes' in the little box below to copy the notebooks, or anything else to cancel.")
print("Note that the little box will fight you for focus.")
print("Keep clicking and you'll eventually win!")
response = input("Proceed")
print(f"The response was {repr(response)}.")
if response != "yes":
    raise RuntimeError("Cancelled")

for base in released:
    print(f"Copying {base}")
    shutil.copyfile(archive_path(base), work_path(base))
# Out:
# You are about to deploy version 0.0.20240412.
# Type 'yes' in the little box below to copy the notebooks, or anything else to cancel.
# Note that the little box will fight you for focus.
# Keep clicking and you'll eventually win!
# The response was 'yes'.
# Copying authoring_leaf_systems.ipynb
# Copying authoring_multibody_simulation.ipynb
# Copying debug_mathematical_program.ipynb
# Copying dynamical_systems.ipynb
# Copying hydroelastic_contact_basics.ipynb
# Copying hydroelastic_contact_nonconvex_mesh.ipynb
# Copying index.ipynb
# Copying licensed_solvers_deepnote.ipynb
# Copying linear_program.ipynb
# Copying mathematical_program.ipynb
# Copying mathematical_program_multibody_plant.ipynb
# Copying multibody_plant_autodiff_mass.ipynb
# Copying nonlinear_program.ipynb
# Copying pyplot_animation_multibody_plant.ipynb
# Copying quadratic_program.ipynb
# Copying rendering_multibody_plant.ipynb
# Copying solver_parameters.ipynb
# Copying sum_of_squares_optimization.ipynb
# ...

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=daec9c67-c271-4556-b3d6-020f0178ac09' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
